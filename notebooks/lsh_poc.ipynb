# %% [markdown]
# # Setting Parameters

# %%
lsh_threshold = 0.2  # Adjust as needed

# %% [markdown]
# # Importing libs

# %%
import pandas as pd
from datasketch import MinHash, MinHashLSH
import re
import time

# %% [markdown]
# # Preprocessing

# %%
# Load your data
df1 = pd.read_csv('../data/matchto-db-records.csv')
df2 = pd.read_csv('../data/source-companies.csv')

# %%
df1.head(2)
# Out:
#       id                                     name                  address_1  \
# 0  11699  Newburyport Five Cents Savings Bank Inc                63 State St
# 1  77176                Tensar International, LLC  2500 Northwinds Pkwy # 50
#
#   address_2         city state    zip_code country              website_url
# 0       NaN  Newburyport    MA  01950-6615     USA  www.newburyportbank.com
# 1       NaN   Alpharetta    GA  30009-2243     USA       www.tensarcorp.com

# %%
df1 = df1[['name', 'website_url']]

# %%
df1.isna().sum()
# Out:
# name              0
# website_url    1887
# dtype: int64

# %%
df1.columns = ['company_1', 'website_1']

# %%
df1.head(2)
# Out:
#                                  company_1                website_1
# 0  Newburyport Five Cents Savings Bank Inc  www.newburyportbank.com
# 1                Tensar International, LLC       www.tensarcorp.com

# %%
df1.website_1.value_counts()
# Out:
# website_1
# www.wellsfargo.com             21
# www.va.gov                     13
# www.chase.com                  11
# www.jpmorgan.com               10
# www.att.com                    10
#                                ..
# www.rojekconsulting.com         1
# www.southernenvironment.org     1
# www.hdtvpromotions.com          1
# www.cdc.gov                     1
# www.brantondejong.com           1
# Name: count, Length: 7383, dtype: int64

# %%
df1.head(2)
# Out:
#                                  company_1                website_1
# 0  Newburyport Five Cents Savings Bank Inc  www.newburyportbank.com
# 1                Tensar International, LLC       www.tensarcorp.com

# %% [markdown]
# ### df1 preprocess complete

# %%
df2.head(2)
# Out:
#   company_name       website              address_1           city state  \
# 0      23andMe   23andme.com       899 W Evelyn Ave  Mountain View    CA
# 1    280 Group  280group.com  142B S Santa Cruz Ave      Los Gatos    CA
#
#        zip
# 0  94041.0
# 1  95030.0

# %%
df2.columns = ['company_2', 'website_2', 'address_2', 'city_2', 'state_2', 'zip_code_2']
df2 = df2[['company_2', 'website_2']]

# %%
df2.head()
# Out:
#       company_2        website_2
# 0       23andMe      23andme.com
# 1     280 Group     280group.com
# 2  5AM Ventures  5amventures.com
# 3         Accel    www.accel.com
# 4       Addepar      addepar.com

# %% [markdown]
# for col in df1.columns:
#     df1[col] = df1[col].apply(preprocess)
#
# for col in df2.columns:
#     df2[col] = df2[col].apply(preprocess)

# %%
df1.drop_duplicates(inplace=True)
df2.drop_duplicates(inplace=True)

# %%
df1.head(2)
# Out:
#                                  company_1                website_1
# 0  Newburyport Five Cents Savings Bank Inc  www.newburyportbank.com
# 1                Tensar International, LLC       www.tensarcorp.com

# %%
df2.head(2)
# Out:
#    company_2     website_2
# 0    23andMe   23andme.com
# 1  280 Group  280group.com

# %%
for dataframe in [df1,df2]:
    for col in dataframe.columns:
        dataframe[col]=dataframe[col].apply(lambda x: str(x).lower())

# %%
df1.website_1 = df1.website_1.apply(lambda x: " ".join(x.split('.')))
df2.website_2 = df2.website_2.apply(lambda x: " ".join(x.split('.')))

# %%
df1['concat_1']=df1.apply(lambda row: ' '.join(map(str, row)), axis=1)
df2['concat_2']=df2.apply(lambda row: ' '.join(map(str, row)), axis=1)

# %% [markdown]
# # Create all possible combos

# %%
# Performing a cross join
df1['key'] = 1
df2['key'] = 1
df = pd.merge(df1, df2, on='key').drop('key', axis=1)

# %%
df.head(2)
# Out:
#                                  company_1                website_1  \
# 0  newburyport five cents savings bank inc  www newburyportbank com
# 1  newburyport five cents savings bank inc  www newburyportbank com
#
#                                             concat_1  company_2     website_2  \
# 0  newburyport five cents savings bank inc www ne...    23andme   23andme com
# 1  newburyport five cents savings bank inc www ne...  280 group  280group com
#
#                  concat_2
# 0     23andme 23andme com
# 1  280 group 280group com

# %%
df1.head(2)
# Out:
#                                  company_1                website_1  \
# 0  newburyport five cents savings bank inc  www newburyportbank com
# 1                tensar international, llc       www tensarcorp com
#
#                                             concat_1  key
# 0  newburyport five cents savings bank inc www ne...    1
# 1       tensar international, llc www tensarcorp com    1

# %%
df1.shape
# Out:
# (9702, 4)

# %%
df.concat_1.nunique()
# Out:
# 9677

# %%
df2.head(2)
# Out:
#    company_2     website_2                concat_2  key
# 0    23andme   23andme com     23andme 23andme com    1
# 1  280 group  280group com  280 group 280group com    1

# %%
df2.shape
# Out:
# (262, 4)

# %%
df2.concat_2.nunique()
# Out:
# 262

# %%
df.head(3)
# Out:
#                                  company_1                website_1  \
# 0  newburyport five cents savings bank inc  www newburyportbank com
# 1  newburyport five cents savings bank inc  www newburyportbank com
# 2  newburyport five cents savings bank inc  www newburyportbank com
#
#                                             concat_1     company_2  \
# 0  newburyport five cents savings bank inc www ne...       23andme
# 1  newburyport five cents savings bank inc www ne...     280 group
# 2  newburyport five cents savings bank inc www ne...  5am ventures
#
#          website_2                      concat_2
# 0      23andme com           23andme 23andme com
# 1     280group com        280 group 280group com
# 2  5amventures com  5am ventures 5amventures com

# %%
df['website_1'] = df['website_1'].str.replace('com', '').str.replace('www', '')
df['website_2'] = df['website_2'].str.replace('com', '').str.replace('www', '')

# %%
df.head(2)
# Out:
#                                  company_1          website_1  \
# 0  newburyport five cents savings bank inc   newburyportbank
# 1  newburyport five cents savings bank inc   newburyportbank
#
#                                             concat_1  company_2  website_2  \
# 0  newburyport five cents savings bank inc www ne...    23andme   23andme
# 1  newburyport five cents savings bank inc www ne...  280 group  280group
#
#                  concat_2
# 0     23andme 23andme com
# 1  280 group 280group com

# %% [markdown]
# # Computing MinHash

# %%
# Function to create MinHash from a company name
def create_minhash(company):
    company = str(company)
    tokens = re.sub(r'\W+', ' ', company.lower()).split()
    m = MinHash()
    for token in tokens:
        m.update(token.encode('utf8'))
    return m

# Compute MinHashes for unique companies in both dataframes
unique_companies_1 = df1['concat_1'].unique()
unique_companies_2 = df2['concat_2'].unique()

minhashes_1 = {company: create_minhash(company) for company in unique_companies_1}
minhashes_2 = {company: create_minhash(company) for company in unique_companies_2}

# Compare hashes for all possible combinations
matches = []

for company1, minhash1 in minhashes_1.items():
    for company2, minhash2 in minhashes_2.items():
        if minhash1.jaccard(minhash2) > lsh_threshold:
            matches.append((company1, company2))

# Output matches
print(len(matches))
# Out:
# 319913

# %%
concat_df = pd.DataFrame(matches, columns=['concat_1', 'concat_2'])

# %%
result_1 = pd.merge(concat_df,df, on=['concat_1', 'concat_2'])

# %%
result_1.concat_1.nunique()
# Out:
# 7716

# %%
result_1.concat_2.nunique()
# Out:
# 256

# %% [markdown]
# # Fuzzy Match

# %%
from fuzzywuzzy import fuzz

# %%
def calculate_fuzzy_score(column1, column2):
    return fuzz.token_set_ratio(str(column1), str(column2))

# List of columns to compare
columns_to_compare = ['company', 'website']

# Create new columns for fuzzy match scores
for column in columns_to_compare:
    result_1[f'{column}_score'] = result_1.apply(lambda x: calculate_fuzzy_score(x[f'{column}_1'], x[f'{column}_2']), axis=1)

# %%
result_1.columns
# Out:
# Index(['concat_1', 'concat_2', 'company_1', 'website_1', 'company_2',
#        'website_2', 'company_score', 'website_score'],
#       dtype='object')

# %%
result_1.sort_values(by=['company_score', 'website_score'], ascending=False,inplace=True)

# %%
final_df = result_1[[
    'company_1',
    'company_2',
    'company_score',
    'website_1',
    'website_2',
    'website_score',
]]

# %%
final_df.head(10)
# Out:
#                               company_1 company_2  company_score  \
# 48489                        google llc    google            100
# 54980   asus computer international inc      asus            100
# 92080                     paypal credit    paypal            100
# 96835                        apple inc.     apple            100
# 166852                      intuit inc.    intuit            100
# 199501                      intuit inc.    intuit            100
# 224419                intel corporation     intel            100
# 275223                   synopsys, inc.  synopsys            100
# 303821                    mongodb, inc.   mongodb            100
# 133249                    fanatics, llc  fanatics            100
#
#                                   website_1  website_2  website_score
# 48489                               google     google             100
# 54980                              asus  tw      asus             100
# 92080                               paypal     paypal             100
# 96835                                apple      apple             100
# 166852                              intuit     intuit             100
# 199501  https:// intuit /privacy/statement/    intuit             100
# 224419                               intel      intel             100
# 275223                            synopsys   synopsys             100
# 303821                             mongodb    mongodb             100
# 133249                    footballfanatics   fanatics              67

# %%
final_df['fuzz_index'] = 0.3*final_df.company_score+0.7*final_df.website_score
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_85395/2254232016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['fuzz_index'] = 0.3*final_df.company_score+0.7*final_df.website_score

# %%
final_df.sort_values(by='fuzz_index',ascending=False,inplace=True)
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_85395/2014474883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.sort_values(by='fuzz_index',ascending=False,inplace=True)

# %%
final_df.columns
# Out:
# Index(['company_1', 'company_2', 'company_score', 'website_1', 'website_2',
#        'website_score', 'fuzz_index'],
#       dtype='object')

# %%
match_df = final_df.sort_values('fuzz_index', ascending=False).groupby(['company_2','website_2']).head(1).reset_index(drop=True)

# %%
match_df.sort_values(by='fuzz_index')
# Out:
#              company_1            company_2  company_score         website_1  \
# 255    fivethirtyeight           sumo logic              8  fivethirtyeight
# 254    schlage lock co              elastic             18               nan
# 253        puccimanuli      hewlett packard             23      puccimanuli
# 252   savvyinsider.com  andreessen horowitz             11               nan
# 251            horchow           invoice2go             35          horchow
# ..                 ...                  ...            ...               ...
# 4       synopsys, inc.             synopsys            100         synopsys
# 3    intel corporation                intel            100            intel
# 2          intuit inc.               intuit            100           intuit
# 1           apple inc.                apple            100            apple
# 0           google llc               google            100           google
#
#       website_2  website_score  fuzz_index
# 255  sumologic               8         8.0
# 254  elastic co             15        15.9
# 253         hp              15        17.4
# 252       a16z              29        23.6
# 251        2go              20        24.5
# ..          ...            ...         ...
# 4     synopsys             100       100.0
# 3        intel             100       100.0
# 2       intuit             100       100.0
# 1        apple             100       100.0
# 0       google             100       100.0
#
# [256 rows x 7 columns]

# %%
match_df.shape
# Out:
# (256, 7)

# %%
match_df.to_csv('text_matching_data.csv',index=False)

# %% [markdown]
# # annotated data

# %%
match_df.sort_values(by='fuzz_index',ascending=False,inplace=True)
match_df.head(20)
# Out:
#                           company_1                  company_2  company_score  \
# 0                        google llc                     google            100
# 5                     mongodb, inc.                    mongodb            100
# 7                     paypal credit                     paypal            100
# 6   asus computer international inc                       asus            100
# 1                        apple inc.                      apple            100
# 4                    synopsys, inc.                   synopsys            100
# 2                       intuit inc.                     intuit            100
# 3                 intel corporation                      intel            100
# 8      mig capital management, inc.  makena capital management             84
# 9                  jps partners inc                gi partners             84
# 10                      alg capital                ggv capital             82
# 11  classified advertising ventures               dcm ventures             80
# 12                      alg capital             bright capital             78
# 13                      alg capital  highland capital partners             78
# 14                      alg capital          altimeter capital             78
# 15                       adobe inc.                 adobe, llc             78
# 17                  the henry group           the westly group             77
# 18                         lw group       the blackstone group             77
# 16             b.g. & m. associates  new enterprise associates             77
# 19          columbus community bank              columbus nova             76
#
#      website_1  website_2  website_score  fuzz_index
# 0      google     google             100       100.0
# 5     mongodb    mongodb             100       100.0
# 7      paypal     paypal             100       100.0
# 6     asus  tw      asus             100       100.0
# 1       apple      apple             100       100.0
# 4    synopsys   synopsys             100       100.0
# 2      intuit     intuit             100       100.0
# 3       intel      intel             100       100.0
# 8          nan        nan            100        95.2
# 9          nan        nan            100        95.2
# 10         nan        nan            100        94.6
# 11         nan        nan            100        94.0
# 12         nan        nan            100        93.4
# 13         nan        nan            100        93.4
# 14         nan        nan            100        93.4
# 15      adobe      adobe             100        93.4
# 17         nan        nan            100        93.1
# 18         nan        nan            100        93.1
# 16         nan        nan            100        93.1
# 19         nan        nan            100        92.8

# %%
true_data = pd.read_csv("../export_data (1).csv")

# %%
true_data.head(1)
# Out:
#                                  job_id company_1 company_2 company_score  \
# 0  08c045ba-7ffb-48bd-ba20-dc2028c8da25   fremont   fremont            ca
#
#   address_1      address_2  address_score                           city_1  \
# 0        ca  48720 kato rd  48720 kato rd  asus computer international inc
#
#   city_2 city_score website_1  website_2  website_score  state_1  state_2  \
# 0   asus   asus  tw     asus         100          100.0      100      100
#
#    state_score  fuzz_index                             Annotation
# 0          100         100  {"Text Matching": {"match": "Match"}}

# %%
# Check for missing values
if true_data['Annotation'].isnull().any():
    # Handle or remove missing values as needed
    true_data = true_data.dropna(subset=['Annotation'])

# Check the structure of dictionaries
def extract_text_matching(annotation):
    if isinstance(annotation, dict) and 'Text Matching' in annotation:
        # Check if 'Text Matching' key exists in the dictionary
        return annotation['Text Matching'].get('match', 'Not Found')
    else:
        return 'Not a dictionary or missing key'

# Apply the function to create a new 'match' column
true_data['match'] = true_data['Annotation'].apply(extract_text_matching)

# %%
true_data['label'] = (true_data.match=="Match").astype(int)

# %%
true_data.columns
# Out:
# Index(['job_id', 'company_1', 'company_2', 'company_score', 'address_1',
#        'address_2', 'address_score', 'city_1', 'city_2', 'city_score',
#        'website_1', 'website_2', 'website_score', 'state_1', 'state_2',
#        'state_score', 'fuzz_index', 'Annotation', 'match', 'label'],
#       dtype='object')

# %%
true_data.columns = ['job_id', 'city_1', 'city_2', 'state_1', 'state_2','address_1',
       'address_2','company_1', 'company_2', 'website_1', 'website_2', 'company_score',  'address_score', 'city_score',
       'website_score', 
       'state_score', 'fuzz_index', 'Annotation', 'match', 'label']

# %%
true_data.head(2)
# Out:
#                                  job_id       city_1       city_2 state_1  \
# 0  08c045ba-7ffb-48bd-ba20-dc2028c8da25      fremont      fremont      ca
# 1  9f0e06ff-e88a-4301-8fb0-6093c68aa0fd  santa clara  santa clara      ca
#
#   state_2                  address_1                  address_2  \
# 0      ca              48720 kato rd              48720 kato rd
# 1      ca  2200 mission college blvd  2200 mission college blvd
#
#                          company_1 company_2  website_1 website_2  \
# 0  asus computer international inc      asus   asus  tw     asus
# 1                intel corporation     intel     intel     intel
#
#    company_score  address_score  city_score  website_score  state_score  \
# 0            100          100.0         100            100          100
# 1            100          100.0         100            100          100
#
#    fuzz_index                             Annotation  match  label
# 0         100  {'Text Matching': {'match': 'Match'}}  Match      1
# 1         100  {'Text Matching': {'match': 'Match'}}  Match      1

# %%
true_data = true_data[['city_1', 'city_2', 'state_1', 'state_2','address_1',
       'address_2','company_1', 'company_2', 'website_1', 'website_2','label']]

# %%
true_data.label.sum()
# Out:
# 8

# %%
df2 = pd.merge(true_data,match_df,on = ['city_1', 'city_2', 'state_1', 'state_2','address_1',
       'address_2','company_1', 'company_2', 'website_1', 'website_2',],how = 'left')

# %%
df2.isna().sum()
# Out:
# city_1            1
# city_2            3
# state_1           3
# state_2           4
# address_1         4
# address_2         5
# company_1         0
# company_2         0
# website_1        43
# website_2        37
# label             0
# company_score    50
# address_score    50
# city_score       50
# website_score    50
# state_score      50
# fuzz_index       50
# dtype: int64

# %%
true_data[true_data.label==1]
# Out:
#               city_1         city_2 state_1 state_2  \
# 0            fremont        fremont      ca      ca
# 1        santa clara    santa clara      ca      ca
# 2      mountain view  mountain view      ca      ca
# 3          cupertino      cupertino      ca      ca
# 4      mountain view  mountain view      ca      ca
# 13         san mateo      san mateo      ca      ca
# 26         sunnyvale      sunnyvale      ca      ca
# 73  colorado springs       san jose      co     NaN
#
#                      address_1                  address_2  \
# 0                48720 kato rd              48720 kato rd
# 1    2200 mission college blvd  2200 mission college blvd
# 2         690 e middlefield rd       690 e middlefield rd
# 3             1 apple park way               apple campus
# 4              2535 garcia ave             2675 coast ave
# 13        1100 park pl ste 300          1100 park pl #300
# 26               701 first ave                701 1st ave
# 73  2424 garden of the gods rd     6280 america center dr
#
#                              company_1                   company_2  \
# 0      asus computer international inc                        asus
# 1                    intel corporation                       intel
# 2                       synopsys, inc.                    synopsys
# 3                           apple inc.                       apple
# 4                          intuit inc.                      intuit
# 13                      alienvault llc                  alienvault
# 26                       yahoo cv, llc                       yahoo
# 73  perspecta enterprise solutions llc  hewlett-packard enterprise
#
#               website_1     website_2  label
# 0              asus  tw         asus       1
# 1                intel         intel       1
# 2             synopsys      synopsys       1
# 3                apple         apple       1
# 4               intuit        intuit       1
# 13   cybersecurity att    alienvault       1
# 26        verizonmedia         yahoo       1
# 73                 hpe           hpe       1

# %% [markdown]
# # Total evaluation

# %%
df.shape
# Out:
# (2617118, 12)

# %%
state_city_match = df[(df.state_1==df.state_2) & (df.city_1==df.city_2)]

# %%
state_city_match
# Out:
#                            company_1                  address_1     city_1  \
# 25685             emerson equity llc       155 bovet rd ste 725  san mateo
# 25695             emerson equity llc       155 bovet rd ste 725  san mateo
# 25697             emerson equity llc       155 bovet rd ste 725  san mateo
# 25704             emerson equity llc       155 bovet rd ste 725  san mateo
# 25743             emerson equity llc       155 bovet rd ste 725  san mateo
# ...                              ...                        ...        ...
# 2617048  dejong branton & associates  6155 almaden expy ste 350   san jose
# 2617077  dejong branton & associates  6155 almaden expy ste 350   san jose
# 2617080  dejong branton & associates  6155 almaden expy ste 350   san jose
# 2617106  dejong branton & associates  6155 almaden expy ste 350   san jose
# 2617115  dejong branton & associates  6155 almaden expy ste 350   san jose
#
#         state_1              website_1  \
# 25685        ca  www emersonequity com
# 25695        ca  www emersonequity com
# 25697        ca  www emersonequity com
# 25704        ca  www emersonequity com
# 25743        ca  www emersonequity com
# ...         ...                    ...
# 2617048      ca  www brantondejong com
# 2617077      ca  www brantondejong com
# 2617080      ca  www brantondejong com
# 2617106      ca  www brantondejong com
# 2617115      ca  www brantondejong com
#
#                                                   concat_1   company_2  \
# 25685    emerson equity llc 155 bovet rd ste 725 san ma...  alienvault
# 25695    emerson equity llc 155 bovet rd ste 725 san ma...      apttus
# 25697    emerson equity llc 155 bovet rd ste 725 san ma...      armory
# 25704    emerson equity llc 155 bovet rd ste 725 san ma...    benevity
# 25743    emerson equity llc 155 bovet rd ste 725 san ma...      dokkio
# ...                                                    ...         ...
# 2617048  dejong branton & associates 6155 almaden expy ...     securly
# 2617077  dejong branton & associates 6155 almaden expy ...        taos
# 2617080  dejong branton & associates 6155 almaden expy ...     tenable
# 2617106  dejong branton & associates 6155 almaden expy ...      xilinx
# 2617115  dejong branton & associates 6155 almaden expy ...     zscaler
#
#                              address_2     city_2 state_2           website_2  \
# 25685                1100 park pl #300  san mateo      ca  www alienvault com
# 25695    1400 fashion island blvd #100  san mateo      ca          apttus com
# 25697                28 e 3rd ave #200  san mateo      ca       www armory io
# 25704               32 w 25th ave #203  san mateo      ca        benevity com
# 25743            1 waters park dr #103  san mateo      ca          dokkio com
# ...                                ...        ...     ...                 ...
# 2617048      111 n market st 4th floor   san jose      ca         securly com
# 2617077                 121 daggett dr   san jose      ca            taos com
# 2617080                            nan   san jose      ca     www tenable com
# 2617106                  2050 logic dr   san jose      ca          xilinx com
# 2617115           100 rose orchard way   san jose      ca         zscaler com
#
#                                                   concat_2
# 25685    alienvault 1100 park pl #300 san mateo ca www ...
# 25695    apttus 1400 fashion island blvd #100 san mateo...
# 25697    armory 28 e 3rd ave #200 san mateo ca www armo...
# 25704    benevity 32 w 25th ave #203 san mateo ca benev...
# 25743    dokkio 1 waters park dr #103 san mateo ca dokk...
# ...                                                    ...
# 2617048  securly 111 n market st 4th floor san jose ca ...
# 2617077           taos 121 daggett dr san jose ca taos com
# 2617080            tenable nan san jose ca www tenable com
# 2617106        xilinx 2050 logic dr san jose ca xilinx com
# 2617115  zscaler 100 rose orchard way san jose ca zscal...
#
# [2931 rows x 12 columns]

# %%
def calculate_fuzzy_score(column1, column2):
    return fuzz.partial_ratio(str(column1), str(column2))

# List of columns to compare
columns_to_compare = ['company', 'address','website']

# Create new columns for fuzzy match scores
for column in columns_to_compare:
    state_city_match[f'{column}_score'] = state_city_match.apply(lambda x: calculate_fuzzy_score(x[f'{column}_1'], x[f'{column}_2']), axis=1)
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_85395/4105871683.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_city_match[f'{column}_score'] = state_city_match.apply(lambda x: calculate_fuzzy_score(x[f'{column}_1'], x[f'{column}_2']), axis=1)

# %%
state_city_match.sort_values(by = ['website_score','company_score','address_score',],ascending = False,inplace=True)
# Out:
# /var/folders/qd/53v0q6g93r5g_dc_bwl8_tlw0000gn/T/ipykernel_85395/1859811242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_city_match.sort_values(by = ['website_score','company_score','address_score',],ascending = False,inplace=True)

# %%
state_city_match.head(20)
# Out:
#                                company_1                   address_1  \
# 428917   asus computer international inc               48720 kato rd
# 1801366                intel corporation   2200 mission college blvd
# 2221717                   synopsys, inc.        690 e middlefield rd
# 1327149                      intuit inc.             2535 garcia ave
# 894748                        apple inc.            1 apple park way
# 1077692                 portola partners  1550 el camino real ste 20
# 1077646                 portola partners  1550 el camino real ste 20
# 1077711                 portola partners  1550 el camino real ste 20
# 1077809                 portola partners  1550 el camino real ste 20
# 1077724                 portola partners  1550 el camino real ste 20
# 1077721                 portola partners  1550 el camino real ste 20
# 1077839                 portola partners  1550 el camino real ste 20
# 1077767                 portola partners  1550 el camino real ste 20
# 1077788                 portola partners  1550 el camino real ste 20
# 1077759                 portola partners  1550 el camino real ste 20
# 1077815                 portola partners  1550 el camino real ste 20
# 1077835                 portola partners  1550 el camino real ste 20
# 1077742                 portola partners  1550 el camino real ste 20
# 1077733                 portola partners  1550 el camino real ste 20
# 591470               autodaq corporation              1130 obrien dr
#
#                 city_1 state_1         website_1  \
# 428917         fremont      ca   www asus com tw
# 1801366    santa clara      ca     www intel com
# 2221717  mountain view      ca  www synopsys com
# 1327149  mountain view      ca    www intuit com
# 894748       cupertino      ca     www apple com
# 1077692     menlo park      ca               nan
# 1077646     menlo park      ca               nan
# 1077711     menlo park      ca               nan
# 1077809     menlo park      ca               nan
# 1077724     menlo park      ca               nan
# 1077721     menlo park      ca               nan
# 1077839     menlo park      ca               nan
# 1077767     menlo park      ca               nan
# 1077788     menlo park      ca               nan
# 1077759     menlo park      ca               nan
# 1077815     menlo park      ca               nan
# 1077835     menlo park      ca               nan
# 1077742     menlo park      ca               nan
# 1077733     menlo park      ca               nan
# 591470      menlo park      ca               nan
#
#                                                   concat_1  \
# 428917   asus computer international inc 48720 kato rd ...
# 1801366  intel corporation 2200 mission college blvd sa...
# 2221717  synopsys, inc. 690 e middlefield rd mountain v...
# 1327149  intuit inc. 2535 garcia ave mountain view ca w...
# 894748   apple inc. 1 apple park way cupertino ca www a...
# 1077692  portola partners 1550 el camino real ste 20 me...
# 1077646  portola partners 1550 el camino real ste 20 me...
# 1077711  portola partners 1550 el camino real ste 20 me...
# 1077809  portola partners 1550 el camino real ste 20 me...
# 1077724  portola partners 1550 el camino real ste 20 me...
# 1077721  portola partners 1550 el camino real ste 20 me...
# 1077839  portola partners 1550 el camino real ste 20 me...
# 1077767  portola partners 1550 el camino real ste 20 me...
# 1077788  portola partners 1550 el camino real ste 20 me...
# 1077759  portola partners 1550 el camino real ste 20 me...
# 1077815  portola partners 1550 el camino real ste 20 me...
# 1077835  portola partners 1550 el camino real ste 20 me...
# 1077742  portola partners 1550 el camino real ste 20 me...
# 1077733  portola partners 1550 el camino real ste 20 me...
# 591470   autodaq corporation 1130 obrien dr menlo park ...
#
#                               company_2  \
# 428917                             asus
# 1801366                           intel
# 2221717                        synopsys
# 1327149                          intuit
# 894748                            apple
# 1077692                     gi partners
# 1077646                 canaan partners
# 1077711       highland capital partners
# 1077809            silver lake partners
# 1077724              interwest partners
# 1077721  institutional venture partners
# 1077839           u.s. venture partners
# 1077767          nexus venture partners
# 1077788                  relay ventures
# 1077759                    morgenthaler
# 1077815              sofinnova ventures
# 1077835                trinity ventures
# 1077742       makena capital management
# 1077733                 kleiner perkins
# 591470        makena capital management
#
#                                         address_2         city_2 state_2  \
# 428917                              48720 kato rd        fremont      ca
# 1801366                 2200 mission college blvd    santa clara      ca
# 2221717                      690 e middlefield rd  mountain view      ca
# 1327149                            2675 coast ave  mountain view      ca
# 894748                               apple campus      cupertino      ca
# 1077692                       2180 sand hill road     menlo park      ca
# 1077646                       2765 sand hill road     menlo park      ca
# 1077711             2420 sand hill road suite 300     menlo park      ca
# 1077809                       2775 sand hill road     menlo park      ca
# 1077724                       2710 sand hill road     menlo park      ca
# 1077721                       3000 sand hill road     menlo park      ca
# 1077839                       2735 sand hill road     menlo park      ca
# 1077767                       2200 sand hill road     menlo park      ca
# 1077788                       3000 sand hill road     menlo park      ca
# 1077759                       2710 sand hill road     menlo park      ca
# 1077815                       3000 sand hill road     menlo park      ca
# 1077835  3000 sand hill road building 4 suite 160     menlo park      ca
# 1077742                       2755 sand hill road     menlo park      ca
# 1077733                           2750 saill road     menlo park      ca
# 591470                        2755 sand hill road     menlo park      ca
#
#               website_2                                           concat_2  \
# 428917     www asus com         asus 48720 kato rd fremont ca www asus com
# 1801366       intel com  intel 2200 mission college blvd santa clara ca...
# 2221717    synopsys com  synopsys 690 e middlefield rd mountain view ca...
# 1327149  www intuit com  intuit 2675 coast ave mountain view ca www int...
# 894748    www apple com      apple apple campus cupertino ca www apple com
# 1077692             nan  gi partners 2180 sand hill road menlo park ca nan
# 1077646             nan  canaan partners 2765 sand hill road menlo park...
# 1077711             nan  highland capital partners 2420 sand hill road ...
# 1077809             nan  silver lake partners 2775 sand hill road menlo...
# 1077724             nan  interwest partners 2710 sand hill road menlo p...
# 1077721             nan  institutional venture partners 3000 sand hill ...
# 1077839             nan  u.s. venture partners 2735 sand hill road menl...
# 1077767             nan  nexus venture partners 2200 sand hill road men...
# 1077788             nan  relay ventures 3000 sand hill road menlo park ...
# 1077759             nan  morgenthaler 2710 sand hill road menlo park ca...
# 1077815             nan  sofinnova ventures 3000 sand hill road menlo p...
# 1077835             nan  trinity ventures 3000 sand hill road building ...
# 1077742             nan  makena capital management 2755 sand hill road ...
# 1077733             nan  kleiner perkins 2750 saill road menlo park ca nan
# 591470              nan  makena capital management 2755 sand hill road ...
#
#          company_score  address_score  website_score
# 428917             100            100            100
# 1801366            100            100            100
# 2221717            100            100            100
# 1327149            100             62            100
# 894748             100             58            100
# 1077692             82             37            100
# 1077646             77             32            100
# 1077711             75             43            100
# 1077809             75             32            100
# 1077724             69             37            100
# 1077721             69             32            100
# 1077839             69             32            100
# 1077767             69             18            100
# 1077788             50             32            100
# 1077759             42             37            100
# 1077815             41             32            100
# 1077835             39             42            100
# 1077742             38             37            100
# 1077733             37             40            100
# 591470              37             27            100
